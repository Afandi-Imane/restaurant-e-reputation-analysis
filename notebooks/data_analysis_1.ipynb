# %%
import nltk
import pandas as pd 
nltk.download('stopwords')
nltk.download('punkt')
import re
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\PC\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\PC\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
df = pd.read_excel(r"C:\Users\PC\Desktop\restaurant_analysis_project_1\notebooks\marakech_clean.xlsx")

# %%
df
# Out:
#                      Nom du Restaurant  \
# 0                           Chez Mmima
# 1                           Chez Mmima
# 2                           Chez Mmima
# 3                           Chez Mmima
# 4                           Chez Mmima
# ...                                ...
# 35123  Le Slimana Restaurant & Rooftop
# 35124  Le Slimana Restaurant & Rooftop
# 35125  Le Slimana Restaurant & Rooftop
# 35126  Le Slimana Restaurant & Rooftop
# 35127  Le Slimana Restaurant & Rooftop
#
#                                                  Adresse   Latitude  \
# 0      Magazin 1, Rue Ibn Habous, résidence Les Trois...  31.629722
# 1      Magazin 1, Rue Ibn Habous, résidence Les Trois...  31.629722
# 2      Magazin 1, Rue Ibn Habous, résidence Les Trois...  31.629722
# 3      Magazin 1, Rue Ibn Habous, résidence Les Trois...  31.629722
# 4      Magazin 1, Rue Ibn Habous, résidence Les Trois...  31.629722
# ...                                                  ...        ...
# 35123                   53 Kaat Benahid, Marrakesh 40000  31.631025
# 35124                   53 Kaat Benahid, Marrakesh 40000  31.631025
# 35125                   53 Kaat Benahid, Marrakesh 40000  31.631025
# 35126                   53 Kaat Benahid, Marrakesh 40000  31.631025
# 35127                   53 Kaat Benahid, Marrakesh 40000  31.631025
#
#        Longitude        Prix  nbr_étoile        Date  \
# 0      -8.005010  50–100 MAD           5  28/05/2025
# 1      -8.005010  50–100 MAD           5  21/08/2025
# 2      -8.005010  50–100 MAD           5  21/08/2025
# 3      -8.005010  50–100 MAD           5  28/07/2025
# 4      -8.005010  50–100 MAD           5  21/08/2025
# ...          ...         ...         ...         ...
# 35123  -7.985442          $$           5  28/08/2024
# 35124  -7.985442          $$           5  28/04/2025
# 35125  -7.985442          $$           5  28/08/2024
# 35126  -7.985442          $$           5  28/07/2025
# 35127  -7.985442          $$           5  28/12/2024
#
#                                              Commentaire Intervalle (MAD)  \
# 0      Il y a des endroits où vous ne venez pas par h...       50–100 MAD
# 1      Un vrai coup de cœur à Marrakech !\nSans doute...       50–100 MAD
# 2      Endroit calme, propre et familiale.\n\nCuisine...       50–100 MAD
# 3      Un restaurant sans prétention mais avec une vr...       50–100 MAD
# 4      Chez Mmima, j’ai fait une très belle découvert...       50–100 MAD
# ...                                                  ...              ...
# 35123  Le cadre est très sympa. Le repas était excell...       70–150 MAD
# 35124  Merci pour l accueil et nous avoir permis de p...       70–150 MAD
# 35125  Très belle expérience au Slimana.\nPlats reche...       70–150 MAD
# 35126  La nourriture est vraiment excellente. Le serv...       70–150 MAD
# 35127  Restaurant haut de gamme pour Marrakech. Mais ...       70–150 MAD
#
#        Prix moyen (MAD)                                Commentaire_nettoye
# 0                    75  a endroits où venez hasard chez mmima fait par...
# 1                    75  vrai coup cœur marrakech sans doute meilleures...
# 2                    75  endroit calme propre familiale cuisine bonne t...
# 3                    75  sans prétention vraie âme chez mmima trouve ca...
# 4                    75  chez mmima fait très belle découverte viande g...
# ...                 ...                                                ...
# 35123               110  cadre très sympa repas excellent service impec...
# 35124               110  merci accueil avoir permis prendre dessert roo...
# 35125               110  très belle expérience slimana plats recherchés...
# 35126               110  nourriture vraiment excellente service anas ir...
# 35127               110  haut gamme marrakech choix travers cuisine mar...
#
# [35128 rows x 11 columns]

# %%
from textblob import TextBlob

def sentiment(text):
    try:
        return TextBlob(text).sentiment.polarity
    except:
        return 0

df['Sentiment'] = df['Commentaire_nettoye'].apply(sentiment)


df.to_excel("marakech_V_finale.xlsx", index=False)
